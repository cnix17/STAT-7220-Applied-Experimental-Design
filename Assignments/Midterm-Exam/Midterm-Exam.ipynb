# %% [markdown]
# <a href="https://colab.research.google.com/github/cnix17/STAT-7220-Applied-Experimental-Design/blob/main/Assignments/Midterm-Exam/Midterm-Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # STAT 7220 - Midterm Exam
# ## Dr. Austin R. Brown
# ### School of Data Science & Analytics
# ### Kennesaw State University
#
# **DUE: October 24, 2025**
#
# **PART 1 INSTRUCTIONS:** Suppose you are a video game controller manufacturer interested in estimating the perceived comfort level of controller grips. To achieve this, you decide to conduct an experiment to assess different material types used for the controller grips (plastic, rubber, silicone, and metal). 10 prototypes of each grip type are manufactured and given to professional gamers (who all play the same game -- Counter-Strike) to test. The gamers use the controllers regularly for one month and then rate the comfort level on a scale from 1 - 10 with greater scores indicating a greater level of perceived comfort (one decimal allowed). The data from this experiment are stored in the Video Game Controllers.xlsx file. With these data, your tasks are:
#
# **Question 1.** Briefly define the objective of this experiment
#
# **Question 2.** Specify the outcome variable
#
# **Question 3.** Specify the independent variable. What are some possible lurking variables?
#
# **Question 4.** Briefly explain why a completely randomized design may be appropriate for this experiment.
#
# **Question 5.** State the null and alternative hypotheses for this experiment.
#
# **Question 6.** Perform appropriate exploratory analysis, including summary statistics **and** data visualizations. Do the results of these analyses support the null or alternative hypothesis more strongly?
#
# **Question 7.** Build a one-way ANOVA model. Test the assumption of normality using **both** a testing and visual method. Do the results of the normality test(s) support the assumption of normality?
#
# **Question 8.** Test the assumption of homogeneity of variance using **both** a testing and visual method. Do the results of the test(s) support the assumption of homogeneity of variance?
#
# **Question 9.** Report the F-statistic and its associated p-value for the test for the treatment factor. Which of our two hypotheses is more strongly supported? Why?
#
# **Question 10.** If the data more strongly support the alternative hypothesis, perform Tukey's HSD post-hoc test to determine which material types are significantly different from each other. If the data more strongly support the null hypothesis, explain why a post-hoc test would not be appropriate.
#
# **Question 11.** Write a brief, contextual conclusion summarizing the results of your analyses.
#
# **PART 2 INSTRUCTIONS:** The same video game controller manufacturing company is now trying to get into the business of creating virtual reality/artificial intelligence content for education. Specifically, they want to build a VR experience to simulate working with elderly patients at a healthcare facility to better prepare nursing students for potential careers in working with elderly patients. To test the VR's effectiveness, a group of 40 undergraduate nursing students were randomly and equally assigned to either a class session utilizing the VR or a class session using a traditional technique for teaching strategies for working with elderly patients. At the end of the class session, a 50 question quiz was given to both groups which measures attitudes toward elderly people. Scores range from 0-50 with greater scores indicating more favorable attitudes toward elderly people and vice versa. However, some students in the group have had prior working experience with elderly people which may have an effect on the quiz outcome. So in the experiment, we document which students have had prior working experience with elderly people and which haven't. The results of the experiment are contained in the `Nursing VR Study.xlsx` file. With these data, your tasks are:
#
# **Question 1.** Briefly define the objective of this experiment
#
# **Question 2.** Specify the outcome variable
#
# **Question 3.** Specify the independent variable and blocking factor. What are some possible lurking variables?
#
# **Question 4.** Briefly explain why a randomized block design would be appropriate here. Similarly, explain why a completely randomized design would not be appropriate.
#
# **Question 5.** State the null and alternative hypotheses for this experiment.
#
# **Question 6.** Perform appropriate exploratory analysis, including summary statistics **and** data visualizations. Do the results of these analyses support the null or alternative hypothesis more strongly?
#
# **Question 7.** Build a two-way ANOVA model. Test the assumption of normality using **both** a visual method and a testing method. Do the results of the normality test(s) support the assumption of normality?
#
# **Question 8.** Test the assumption of homogeneity of variance using **both** a visual method and a testing method. Do the results of the test(s) support the assumption of homogeneity of variance?
#
# **Question 9.** Report the F-statistic and its associated p-value for the treatment effect. Which of our two hypotheses is more strongly supported? Why?
#
# **Question 10.** If the data more strongly support the alternative hypothesis, perform Tukey's HSD post-hoc test to determine which levels of the treatment effect are significantly different from each other. If the data more strongly support the null hypothesis, explain why a post-hoc test would not be appropriate.
#
# **Question 11.** Write a brief, contextual conclusion summarizing the results of your analyses, including potential limitations of this experiment.
#
# **PART 3 INSTRUCTIONS:** Please briefly respond to the following questions:
#
# **Question 1.** Give a reason why one-factor CRD wouldn't generally be appropriate for studies involving human participants.
#
# **Question 2.** What is the purpose of post-hoc tests?
#
# **Question 3.** Explain the difference between RBD and LSD.
#
# **Question 4.** Explain why randomization is important in designing experiments.
#
# **Question 5.** Explain why replication is important in designing experiments.

# %%
# === COURSE REPO SETUP === #

# 1. ENTER your GitHub username (the one that owns your fork)
github_username = "cnix17"

# 2. Name of the repo (don't change unless your fork name is different)
repo_name = "STAT-7220-Applied-Experimental-Design"

# 3. Build the full repo URL for cloning
repo_url = f"https://github.com/{github_username}/{repo_name}.git"

import os

# --- Detect if we're already in a repo ---
cwd = os.getcwd()
if cwd.endswith(repo_name):
    print(f"✅ Already inside repo folder: {cwd}")
else:
    # --- If the repo folder exists, check if it's nested ---
    if os.path.exists(repo_name):
        print(f"⚠️ Found existing folder '{repo_name}'. Skipping clone to avoid nesting.")
    else:
        print(f"📥 Cloning repo from {repo_url}...")
        os.system(f"git clone {repo_url}")

    # --- Change to repo directory ---
    if os.path.exists(repo_name):
        os.chdir(repo_name)
        print(f"📂 Changed directory to: {os.getcwd()}")
    else:
        print("❌ ERROR: Repo folder not found. Please check your GitHub username.")

# --- Check if this is the instructor's repo instead of student's fork ---
# This command needs to be run from within the repository directory
remote_url = os.popen("git config --get remote.origin.url").read().strip()

if "abrown9008" in remote_url:
    print("⚠️ WARNING: You are working in the instructor's repo, not your fork!")
    print("💡 Please fork the repo to your own account and update `github_username` above.")
else:
    print(f"🔗 Connected to fork at: {remote_url}")

# Set Today's Directory #

today_dir = "Assignments/Midterm-Exam"
os.chdir(today_dir)
print(f"📂 Changed directory to: {os.getcwd()}")
# Out:
# 📥 Cloning repo from https://github.com/cnix17/STAT-7220-Applied-Experimental-Design.git...
# 📂 Changed directory to: /content/STAT-7220-Applied-Experimental-Design
# 🔗 Connected to fork at: https://github.com/cnix17/STAT-7220-Applied-Experimental-Design.git
# 📂 Changed directory to: /content/STAT-7220-Applied-Experimental-Design/Assignments/Midterm-Exam

# %%
#Question 1

# The objective of the this experiement is to determine whether the grip material affects the average comfort rating of video game controllers perceived by the professional gamers.

# %%
#Question 2
#The outcome variable is "Comfort", defined as the comfort rating of each grip material measured on a 1-10 scale.

# %%
#Question 3
#The independent variable is "Material" with four levels: Plastic, Rubber, Metal, Silicone
#Possible lurking variables include hand size, duration of play, familiarity of controller, comfort tolerance differences, etc

# %%
#Question 4
#CRD is appropriate because each participant is being randomly assigned a controller grip type and all play the same game. Randomization balances out any lurking variables across groups, and only one treatment factor is manipulated.

# %%
#Question 5
# The null hypothesis is: μPlastic = μRubber = μSilicone = μMetal
# The alternative hypothesis is: At least one mean comfort rating is different

# %%
#Question 6

#Exploratory Analysis
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

#load the data
df = pd.read_excel("Video Game Controllers.xlsx")

print(df.head())


#Summary stats by material

summary = df.groupby("Material")["Comfort"].describe()
print("Summary Stats by Material:")
print(summary)



#Boxplot
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x="Material", y="Comfort", palette="Set2")
sns.swarmplot(data=df, x="Material", y="Comfort", color="black", alpha=0.5)
plt.title("Comfort Ratings by Material")
plt.xlabel("Material")
plt.ylabel("Comfort Rating")
plt.show()


#Histogram for each group
materials = df["Material"].unique()
fig, axes = plt.subplots(2, 2, figsize=(10,7))
for mat, ax in zip(materials, axes.flatten()):
    sns.histplot(df[df["Material"]==mat]["Comfort"], kde=True, ax=ax)
    ax.set_title(f"{mat} Comfort Distribution")
plt.tight_layout()
plt.show()

#Preliminary one-way ANOVA for reference
f_stat, p_val = stats.f_oneway(
    *[df[df["Material"]==mat]["Comfort"] for mat in df["Material"].unique()]
)
print(f"Preliminary ANOVA F={f_stat:.3f}, p={p_val:.4f}")






#Interpretation
#Summary table: We are looking at means & standard deviation
#Boxplot: Shows us the median and spread by group
#Histogram: Checking the shape of distributions
#p-value preview: if p < 0.05, this will hint that differences may exist

#Our exploratory analysis shows clear differences in mean comfort rating between materials, with silicone having the highest avg comfort and metal the lowest.
#Visualizations show reasonably normal distributions per group
# The preliminary ANOVA yields a p-value <0.001, providing strong evidence against the null hypothesis. this suggests that at least one material type differs significantly in perceived comfort
# Out:
#   Material  Comfort
# 0  Plastic      5.6
# 1  Plastic      5.9
# 2  Plastic      6.3
# 3  Plastic      5.7
# 4  Plastic      5.6
# Summary Stats by Material:
#           count  mean       std  min    25%   50%    75%  max
# Material
# Metal      10.0  4.95  0.538000  4.2  4.450  5.05  5.375  5.6
# Plastic    10.0  5.89  0.448330  5.2  5.625  5.80  6.125  6.8
# Rubber     10.0  6.57  0.860297  5.3  6.050  6.35  6.975  8.0
# Silicone   10.0  8.32  0.689283  7.3  7.800  8.50  8.875  9.2
# /tmp/ipython-input-3371113148.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="Material", y="Comfort", palette="Set2")
# Preliminary ANOVA F=47.478, p=0.0000

# %%
#Question 7

#Normality assumption
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# Build one-way ANOVA model
model = ols('Comfort ~ C(Material)', data=df).fit()

# Get residuals
residuals = model.resid

#Shapiro-Wilk test
shapiro_stat, shapiro_p = shapiro(residuals)
print(f"Shapiro-Wilk Test: Statistic={shapiro_stat:.4f}, p={shapiro_p:.4f}")

#Q-Q Plot
sm.qqplot(residuals, line ='s')
plt.title("Q-Q Plot of Residuals")
plt.show()

#Histogram of residuals
sns.histplot(residuals, kde=True)
plt.title("Histogram of Residuals")
plt.show()



#Interpretation
#The Shapiro-Wilk test returned a p-value of 0.9509, which is greater than 0.05. In turn, we fail to reject the null hypothesis of normality.
#Both the Q-Q plot and histogram of residuals indicate that the data are approximately normally distributed
# The assumption of normality is met for the ANOVA model
# Out:
# Shapiro-Wilk Test: Statistic=0.9885, p=0.9509

# %%
#Question 8

from scipy.stats import levene
import matplotlib.pyplot as plt

# --- Levene's Test for Homogeneity of Variance ---
groups = [df[df["Material"] == mat]["Comfort"] for mat in df["Material"].unique()]
lev_stat, lev_p = levene(*groups)
print(f"Levene's Test: Statistic={lev_stat:.4f}, p-value={lev_p:.4f}")

# --- Residuals vs. Fitted Plot ---
fitted = model.fittedvalues
residuals = model.resid

plt.scatter(fitted, residuals)
plt.axhline(0, color='red', linestyle='--')
plt.title("Residuals vs. Fitted Values")
plt.xlabel("Fitted values")
plt.ylabel("Residuals")
plt.show()



#Interpretation
#Levene’s test yielded a p-value of 0.2679, which is greater than 0.05. Therefore, we fail to reject the null hypothesis that the variances across groups are equal.
# Additionally, the residual vs. fitted plot shows a random scatter of points around zero without any obvious funnel or pattern.
# These results indicate that the assumption of homogeneity of variance is met / satisfied
# Out:
# Levene's Test: Statistic=1.3685, p-value=0.2679

# %%
#Question 9

from statsmodels.stats.anova import anova_lm

# Run ANOVA table
anova_table = anova_lm(model, typ=2)
print(anova_table)

#Interpretation
#The one-way ANOVA revealed a statistically significant effect of grip material on comfort ratings, F(3, 36) = 47.48, p < 0.001.
# This extremely small p-value provides evidence against the null hypothesis, indicating that at least one material’s mean comfort rating is significantly different from the others
# Our decision is to reject the null hypothesis
# Out:
#                sum_sq    df          F        PR(>F)
# C(Material)  60.73675   3.0  47.478405  1.348029e-12
# Residual     15.35100  36.0        NaN           NaN

# %%
#Question 10
import matplotlib.pyplot as plt
from statsmodels.stats.multicomp import pairwise_tukeyhsd, MultiComparison

# Pairwise Tukey HSD
mc = MultiComparison(df['Comfort'], df['Material'])
tukey = mc.tukeyhsd(alpha=0.05)
print(tukey.summary())


#Compact Letter Display (which groups are statistically the same)
# This gives us group letters like A/B; groups sharing a letter are NOT significantly different

def compact_letter_display(tukey_result):
    groups = mc.groupsunique
    reject_table = pd.DataFrame(tukey_result._results_table.data[1:],
                                columns=tukey_result._results_table.data[0])
    # build adjacency of "no difference"
    k = len(groups)
    same = {g:set([g]) for g in groups}
    for _, row in reject_table.iterrows():
        a, b, reject = row['group1'], row['group2'], row['reject']
        if not reject:
            same[a].add(b)
            same[b].add(a)

    # greedy letter assignment
    letters = {}
    used_letters = []
    for g in sorted(groups, key=lambda x: df[df['Material']==x]['Comfort'].mean(), reverse=True):
        placed = False
        for L in used_letters:
            # can g join letter L if compatible with all groups already there?
            if all((h in same[g]) for h in letters if letters[h]==L):
                letters[g] = L
                placed = True
                break
        if not placed:
            newL = chr(ord('A')+len(used_letters))
            used_letters.append(newL)
            letters[g] = newL
    return letters

letters = compact_letter_display(tukey)
print("\nCompact Letter Display (same letter = not significantly different):")
for g, L in sorted(letters.items()):
    print(f"{g}: {L}")

#Show means with letters, sorted
means = df.groupby("Material")["Comfort"].mean().sort_values(ascending=False)
mean_letters = pd.DataFrame({"Mean": means})
mean_letters["Group"] = [letters[g] for g in mean_letters.index]
print("\nGroup means with CLD:\n", mean_letters)



#Interpretation
# Silicone had significantly higher comfort than all other materials.
# Rubber and Plastic were each significantly higher than Metal, but not significantly different from each other.
# Metal had the lowest comfort ratings.
# Compact letter display results showed Silicone (A) > Rubber (B) / Plastic (B) > Metal (C).
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1  group2  meandiff p-adj   lower  upper  reject
# ------------------------------------------------------
#   Metal  Plastic     0.94 0.0139  0.1535 1.7265   True
#   Metal   Rubber     1.62    0.0  0.8335 2.4065   True
#   Metal Silicone     3.37    0.0  2.5835 4.1565   True
# Plastic   Rubber     0.68 0.1104 -0.1065 1.4665  False
# Plastic Silicone     2.43    0.0  1.6435 3.2165   True
#  Rubber Silicone     1.75    0.0  0.9635 2.5365   True
# ------------------------------------------------------
#
# Compact Letter Display (same letter = not significantly different):
# Metal: C
# Plastic: B
# Rubber: B
# Silicone: A
#
# Group means with CLD:
#            Mean Group
# Material
# Silicone  8.32     A
# Rubber    6.57     B
# Plastic   5.89     B
# Metal     4.95     C

# %%
# Question 11
# The goal of this experiment was to assess whether different controller grip materials lead to different levels of perceived comfort among professional gamers.
# The exploratory analysis revealed clear differences in average comfort ratings, with Silicone grips scoring the highest and Metal grips scoring the lowest.
# Assumption checks for one-way ANOVA were satisfied (Shapiro–Wilk p = 0.9509, Levene’s test p = 0.2679), confirming the suitability of the analysis.
# The ANOVA showed a statistically significant effect of material on comfort, F(3, 36) = 47.48, p < 0.001.
# Tukey’s HSD post-hoc test indicated that Silicone was significantly more comfortable than Rubber, Plastic, and Metal, while Rubber and Plastic were both significantly more comfortable than Metal.
# No significant difference was found between Rubber and Plastic.
# Compact letter display confirmed the ranking Silicone (A) > Rubber/Plastic (B) > Metal (C).
#This siggests that Silicone is the optimal choice for maximizing user comfort, while Metal offers the least comfort and shoul be avoided
# The results provide statistical evidence to support material selection in future product development

# %%
# Question 1 Section 2

# The objective of this experiment is to evaluate whether using VR technology to teach nursing students strategies for working with elderly patients results in different attitude scores compared to using a traditional teaching method.

# %%
# Question 2 Section 2

# The outcome variable is the attitude score (0–50), measured after the class session.
# Higher scores indicate more favorable attitudes toward elderly patients.

# %%
# Question 3 Section 2
#Independent variable (treatment): Teaching Method (VR vs Traditional)
#Blocking factor: Prior Experience (Yes or No)
#Possible lurking variables: GPA, clinical backgrounnd, instructor variability, session time, baseline attitudes, age of students

# %%
# Question 4 Section 2
# A randomized block design is appropriate because prior experience with elderly patients may influence the outcome (attitude scores).
# By blocking on this variable, we control for its variability and increase the precision of the treatment comparison.
# Why a CRD would not be appropiate:
  # A CRD ignored Prior Experience, so experience-related differences end up in the residual (MSE), inflating error variance and reducing power to detect the method effect.
  # If randomization happens to produce imbalance in experience across methods in your realized sample, CRD can also confound the treatment comparison (apparent method differences could be partly due to experience).
  # Blocking guarantees like-with-like comparisons (VR vs Traditional within each experience level), which CRD does not.


  #Code to justify why CRD would be suboptimal by demonstrating an experience effect

import pandas as pd
from scipy.stats import ttest_ind

nursing = pd.read_excel("Nursing VR Study.xlsx")
# Check the actual column names in the nursing dataset
print(nursing.columns.tolist())

# Rename columns to match what we've been using in the analysis
nursing = nursing.rename(columns={
    'Method': 'Teaching_Method',
    'Experience': 'Prior_Experience',
    'Score': 'Attitude_Score'
})

print(nursing.columns)  # should now show the new names

from scipy.stats import ttest_ind
import pandas as pd

# Check cell counts
print("Cell counts:")
print(pd.crosstab(nursing['Teaching_Method'], nursing['Prior_Experience']))

# Look at experience effect collapsed across teaching methods
exp_groups = nursing.groupby('Prior_Experience')['Attitude_Score']
print("\nMeans by Prior_Experience:")
print(exp_groups.mean())
print("\nSDs by Prior_Experience:")
print(exp_groups.std())

# t-test for quick experience effect check
a = nursing.loc[nursing['Prior_Experience'] == 'Yes', 'Attitude_Score']
b = nursing.loc[nursing['Prior_Experience'] == 'No',  'Attitude_Score']
t_stat, p_val = ttest_ind(a, b, equal_var=True)
print(f"\nExperience effect (pooled): t={t_stat:.3f}, p={p_val:.4f}")

if p_val < 0.05:
    print("=> Prior experience significantly affects scores. RBD justified.")
else:
    print("=> Blocking still prudent even if not significant, to control variance.")
# Out:
# ['Method', 'Experience', 'Score']
# Index(['Teaching_Method', 'Prior_Experience', 'Attitude_Score'], dtype='object')
# Cell counts:
# Prior_Experience  No Prior Experience  Prior Experience
# Teaching_Method
# Traditional                        10                10
# VR                                 10                10
#
# Means by Prior_Experience:
# Prior_Experience
# No Prior Experience    35.90
# Prior Experience       36.15
# Name: Attitude_Score, dtype: float64
#
# SDs by Prior_Experience:
# Prior_Experience
# No Prior Experience    7.114847
# Prior Experience       8.725492
# Name: Attitude_Score, dtype: float64
#
# Experience effect (pooled): t=nan, p=nan
# => Blocking still prudent even if not significant, to control variance.
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/deprecation.py:234: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return f(*args, **kwargs)

# %%
#Question 5 Section 2
# The null hypothesis is μVR = μTraditional
# Alternative hypothesis is that there is a difference in mean attitude scores between two teaching methods.

# %%
#Question 5 Section 2

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.graphics.factorplots import interaction_plot

# Load & clean
nursing = pd.read_excel("Nursing VR Study.xlsx").rename(columns={
    'Method': 'Teaching_Method',
    'Experience': 'Prior_Experience',
    'Score': 'Attitude_Score'
})

# Drop missing rows if any
nursing = nursing[['Teaching_Method', 'Prior_Experience', 'Attitude_Score']].dropna()
nursing['Teaching_Method'] = nursing['Teaching_Method'].astype(str) # Convert to string
nursing['Prior_Experience'] = nursing['Prior_Experience'].astype(str) # Convert to string


# Summary stats
by_method = nursing.groupby('Teaching_Method')['Attitude_Score'].describe()
by_exp = nursing.groupby('Prior_Experience')['Attitude_Score'].describe()
by_cell = nursing.groupby(['Teaching_Method','Prior_Experience'])['Attitude_Score'].describe()

print("\nSummary by Teaching Method:\n", by_method)
print("\nSummary by Prior Experience:\n", by_exp)
print("\nSummary by Method x Experience:\n", by_cell)

# Boxplot: Treatment effect by block
plt.figure(figsize=(8,5))
sns.boxplot(data=nursing, x='Teaching_Method', y='Attitude_Score', hue='Prior_Experience')
plt.title('Attitude Scores by Teaching Method and Prior Experience')
plt.show()

# Interaction plot
plt.figure(figsize=(8,5))
interaction_plot(
    x=nursing['Teaching_Method'],
    trace=nursing['Prior_Experience'],
    response=nursing['Attitude_Score'],
    colors=['blue', 'red']
)
plt.title('Interaction: Teaching Method × Prior Experience')
plt.ylabel('Mean Attitude Score')
plt.show()


#Interpretation

#The descriptive statistics show that students in the VR group had a notably higher mean attitude score (M = 40.75, SD = 6.90) than those in the Traditional group (M = 31.30, SD = 5.68).
# Students with prior experience (M = 36.15) and those without prior experience (M = 35.90) had similar overall scores, suggesting a weak block effect.
# The boxplots illustrate clear separation between VR and Traditional groups, with VR consistently higher across both experience levels.
# The interaction plot shows approximately parallel lines, indicating little to no interaction between Teaching Method and Prior Experience.
# These exploratory findings support the alternative hypothesis that teaching method affects attitude scores.”
# Out:
# Summary by Teaching Method:
#                   count   mean       std   min   25%   50%    75%   max
# Teaching_Method
# Traditional       20.0  31.30  5.676359  20.0  27.5  32.0  33.75  42.0
# VR                20.0  40.75  6.896796  25.0  36.0  41.0  47.00  50.0
#
# Summary by Prior Experience:
#                       count   mean       std   min    25%   50%   75%   max
# Prior_Experience
# No Prior Experience   20.0  35.90  7.114847  25.0  31.75  36.0  39.0  50.0
# Prior Experience      20.0  36.15  8.725492  20.0  31.25  36.0  43.0  50.0
#
# Summary by Method x Experience:
#                                       count  mean       std   min    25%   50%  \
# Teaching_Method Prior_Experience
# Traditional     No Prior Experience   10.0  31.5  5.060742  25.0  28.00  31.5
#                 Prior Experience      10.0  31.1  6.505553  20.0  26.75  32.0
# VR              No Prior Experience   10.0  40.3  6.183311  32.0  36.25  39.0
# ...

# %%
#Question 7 Section 2
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy.stats import shapiro
import seaborn as sns
import matplotlib.pyplot as plt

# Two-way ANOVA model
model_2way = ols('Attitude_Score ~ C(Teaching_Method) + C(Prior_Experience)', data=nursing).fit()

# Shapiro–Wilk test on residuals
residuals = model_2way.resid
shapiro_stat, shapiro_p = shapiro(residuals)
print(f"Shapiro-Wilk Test: Statistic={shapiro_stat:.4f}, p={shapiro_p:.4f}")

# Q-Q plot
sm.qqplot(residuals, line='s')
plt.title("Q-Q Plot of Residuals (Two-Way ANOVA)")
plt.show()

# Histogram of residuals
sns.histplot(residuals, kde=True)
plt.title("Histogram of Residuals (Two-Way ANOVA)")
plt.show()

#Interpretation
# The Shapiro–Wilk test returned a p-value of 0.3495, which is greater than the 0.05 significance level. Therefore, we fail to reject the null hypothesis of normality.
# The Q–Q plot and histogram show the residuals are approximately normally distributed, supporting the normality assumption of the two-way ANOVA model.
# Out:
# Shapiro-Wilk Test: Statistic=0.9696, p=0.3495

# %%
#Question 8 Section 2

from scipy.stats import levene
import matplotlib.pyplot as plt

# Levene's test across the 4 groups (Method x Experience)
groups = [g['Attitude_Score'].values
          for _, g in nursing.groupby(['Teaching_Method','Prior_Experience'])]

lev_stat, lev_p = levene(*groups)
print(f"Levene's Test: Statistic={lev_stat:.4f}, p-value={lev_p:.4f}")

# Residual vs fitted plot
fitted = model_2way.fittedvalues
residuals = model_2way.resid

plt.scatter(fitted, residuals)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.title('Residuals vs Fitted Values (Two-Way ANOVA)')
plt.show()


#Interpretation

#Levene’s test yielded a p-value of 0.7634, which is greater than 0.05. Therefore, we fail to reject the null hypothesis of equal variances across groups.
# Additionally, the residual vs. fitted plot does not show any noticeable pattern or heteroscedasticity. These results support the assumption of homogeneity of variance for the two-way ANOVA model
# Out:
# Levene's Test: Statistic=0.3864, p-value=0.7634

# %%
#Question 9 Section 2
from statsmodels.stats.anova import anova_lm

anova_table_2way = anova_lm(model_2way, typ=2)
print(anova_table_2way)


#Interpretation

# The two-way ANOVA revealed a significant main effect of Teaching Method on attitude scores, F(1, 37) = 21.81, p < 0.001, indicating that students in the VR condition scored significantly higher than those in the Traditional condition.
#There was no significant effect of Prior Experience, F(1, 37) = 0.015, p = 0.902, suggesting that prior experience with elderly patients did not influence attitude scores in this sample. Since the block variable was not significant, it did not account for much variability, but including it still helps ensure control for potential confounding.
#These results strongly support rejecting the null hypothesis for Teaching Method in favor of the alternative.
# Out:
#                        sum_sq    df          F    PR(>F)
# C(Teaching_Method)    893.025   1.0  21.805174  0.000039
# C(Prior_Experience)     0.625   1.0   0.015261  0.902353
# Residual             1515.325  37.0        NaN       NaN

# %%
# Question 10 Section 2
# Since Teaching_Method has just two levels (VR vs Traditional), the ANOVA and Tukey HSD are equivalent — so we can note the following:
# Post-hoc tests are not required because there are only two levels of the treatment factor. The significant ANOVA result already indicates that VR and Traditional groups differ.

# %%
#Question 11 Section 2

# The experiment evaluated whether a VR-based instructional method improves nursing students’ attitudes toward elderly patients compared with a traditional lecture. Normality (p = 0.3495) and homogeneity of variance (p = 0.7634) assumptions were satisfied.
# The two-way ANOVA showed a significant main effect of Teaching Method, F(1, 37) = 21.81, p < 0.001, with students in the VR group (M = 40.75) scoring markedly higher than those in the Traditional group (M = 31.30).
# The blocking factor Prior Experience was not significant, F(1, 37) = 0.02, p = 0.90, indicating that prior work with elderly patients did not meaningfully influence attitudes.

# These findings provide strong evidence that the VR teaching method leads to more favorable attitudes toward elderly patients.
# Although prior experience had little measurable effect, blocking on it helped ensure that differences were due to the teaching method rather than background variation.
#The results suggest that integrating immersive VR content can be an effective strategy for improving nursing students’ empathy and preparedness for geriatric care.”

# %%
#Question 1 Section 3

# Because humans vary a lot on important characteristics (e.g., prior ability, age, baseline attitudes), a one-factor completely randomized design (CRD) tends to:
 # Leave major sources of variability in the error term
 # Risk imbalance/confounding if those traits aren't evenly split by chance
 # Ignore ethical/practical needs to ensure comparability
 # Be more vulnerable to noncompliance/attrition effects that differ by subgroup
 # Hence, the designs that control person-level heterogeneity (RBD, matched pairs, crossover) are usually preferred.

# %%
# Question 2 Section 3
# The purpose of post-hoc tests are used after a statistically significant overall ANOVA to determine which specific group means differ from each other while controlling the overall Type I error rate.
# ANOVA only tells us that at least one group differs.
# Post-hoc tests identify where those differences occur.
# They adjust for multiple comparisons, ensuring that the probability of making a false positive error across all pairwise tests stays at or below the chosen significance level

# %%
#Question 3 Section 3
#RBD:
 # Participants or experimental units are grouped into “blocks” based on a factor that is expected to influence the outcome (e.g., prior experience, age group, skill level).
 # Within each block, treatments are randomly assigned
 # The goal is to remove variability due to the blocking factor from the error term
 # Useful when you know one major nuisance variable you want to control

 #LSD:
 # Used when there are two blocking factors (e.g., day and time, or gender and location) in addition to the treatment.
 # Each treatment appears exactly once in each row and column, balancing across both blocking factors
 # This design controls for two sources of nuisance variability without requiring a full factorial design
 # Efficient design when multiple nusiance factors must be controlled

 #Key takeway: LSD is essentially an extension of RBD to two blocking factors

# %%
#Question 4 Section 3

# Randomization is a core principle of experimental design because it helps ensure that treatment groups are comparable and that uncontrolled or unknown factors do not systematically bias the results.
# It reduces bias: Random assignment spreads both known and unknown nuisance variables evenly across groups, minimizing confounding.
# Suppoprts valid statistical inference: It justifies the use of probability theory in hypothesis testing, making p-values and confidence intervals meaningful.
# Improves internal validity: It strengthens the causal interpretation of treatment effects by ensuring group differences are due to the treatment, not pre-existing differences.
# Simplifies analysis: With proper randomization, residual error is “noise,” not hidden structure, making model assumptions easier to meet.

# %%
#Question 5 Section 3

# Replication means repeating treatments on multiple experimental units (e.g., participants, test subjects, or trials) rather than relying on a single observation per treatment.
 # It is one of the three fundamental principles of experimental design (along with randomization and blocking).

# It increases precision: Replication reduces the impact of random variation (noise) and gives more stable estimates of treatment effects.
# Allows estimation of experimental error: With multiple observations per group, we can calculate residual variance and conduct valid significance tests.
# Improves power: More replications mean greater ability to detect real differences between treatments.
# Enhances generalizability: Results are less likely to be due to anomalies in a small or unrepresentative sample.
# Supports reproducibility: Replication strengthens the credibility of findings and allows others to verify results.
